# %%
from pydantic import BaseModel, Field
from typing import Optional, Dict, List, ForwardRef
from intervaltree import IntervalTree, Interval
import pandas as pd
from concurrent.futures import ProcessPoolExecutor
import hashlib

# %%
HDR = ['chr', 'src', 'feature_type', 'start', 'end', 'score', 'strand', 'frame', 'attributes']

# %%
def load_attributes(s: str, kv_sep: str = '=') -> dict:
    return {
        k.strip(): v.strip()
        for x in s.strip().split(';') if x
        for k, v in [x.strip().split(kv_sep, 1)]
    }

# %%
GFeatureRef = ForwardRef("GFeature")

g2t_map = dict()
g2t_map_2 = dict()

class GFeature(BaseModel):
    chr : str
    src : str
    feature_type : str
    start : int
    end : int
    score : Optional[float]
    strand : str # ['.', '-', '+']
    frame : str # ['.', '0', '1', '2']
    attributes : Dict[str, str]
    _parent : Optional[str] = None
    _id : Optional[str] = None
    _hash : Optional[str] = None

    def __init__(self, **data):
        super().__init__(**data)
        self._infer_id()
        self._hash_id()
        self._infer_parent()

    def _infer_id(self):
        for k, v in self.attributes.items():
            if 'id' in k.lower():
                self._id = v
                break
    
    def _infer_parent(self):
        for k, v in self.attributes.items():
            if 'parent' in k.lower():
                self._parent = v
                break
                
    def _hash_id(self):
        raw = f"{self.chr}{self.strand}-{self.start}-{self.end}"
        self._hash = hashlib.sha256(raw.encode()).hexdigest()
        
    def __repr__(self) -> str:
        return f"{self.feature_type}:{self._id},{self.strand},{self.start}-{self.end},{self._hash}"
    
    def __eq__(self, o) -> bool:
        return o.chr == self.chr and \
            o.strand == self.strand and \
            o.start == self.start and \
            o.end == self.end

class Gene(GFeature):
    children : Dict[str, GFeature]

class Transcript(GFeature):
    children : IntervalTree

class Exon(GFeature):
    child : GFeature
    
def pd_row2gfeature(row):
    try:
        gfeat = GFeature(
            chr = row['chr'],
            src = row['src'],
            feature_type = row['feature_type'],
            start = row['start'],
            end = row['end'],
            score = None if row['score'] == '.' else row['score'],
            strand = row['strand'],
            frame = row['frame'],
            attributes = load_attributes(row['attributes'])
        )
    except Exception as e:
        raise RuntimeError(f"error while converting pd series to GFeature: {e}")
    return gfeat
# Out:
#   Cell In[147], line 53
#     children :
#                ^
# SyntaxError: invalid syntax

# %%
fn = "/ccb/salz4-3/hji20/hg002-q100-annotation/data/chm13v2.0_RefSeq_Liftoff_v5.2.gff3"

# %%
df = pd.read_csv(fn, sep='\t', comment='#', header=None)
df.columns = HDR
df.head()
# Out:
#     chr      src feature_type  start    end score strand frame  \
# 0  chr1  Liftoff         gene   6047  13941     .      -     .
# 1  chr1  Liftoff   transcript   6047  13941     .      -     .
# 2  chr1  Liftoff         exon   6047   6420     .      -     .
# 3  chr1  Liftoff         exon  12078  12982     .      -     .
# 4  chr1  Liftoff         exon  13445  13579     .      -     .
#
#                                           attributes
# 0  ID=LOC124900618;gene_name=LOC124900618;db_xref...
# 1  ID=XR_002958507.2;Parent=LOC124900618;db_xref=...
# 2  Parent=XR_002958507.2;db_xref=GeneID:124900618...
# 3  Parent=XR_002958507.2;db_xref=GeneID:124900618...
# 4  Parent=XR_002958507.2;db_xref=GeneID:124900618...

# %%
df.head()
# Out:
#     chr      src feature_type  start    end score strand frame  \
# 0  chr1  Liftoff         gene   6047  13941     .      -     .
# 1  chr1  Liftoff   transcript   6047  13941     .      -     .
# 2  chr1  Liftoff         exon   6047   6420     .      -     .
# 3  chr1  Liftoff         exon  12078  12982     .      -     .
# 4  chr1  Liftoff         exon  13445  13579     .      -     .
#
#                                           attributes
# 0  ID=LOC124900618;gene_name=LOC124900618;db_xref...
# 1  ID=XR_002958507.2;Parent=LOC124900618;db_xref=...
# 2  Parent=XR_002958507.2;db_xref=GeneID:124900618...
# 3  Parent=XR_002958507.2;db_xref=GeneID:124900618...
# 4  Parent=XR_002958507.2;db_xref=GeneID:124900618...

# %%
feature_types = df['feature_type'].unique()
df_by_feature_type = dict()

for x in feature_types:
    df_by_feature_type[x] = df[df['feature_type'] == x]

# %%
def objectify_df(df):
    res = df.apply(pd_row2gfeature, axis=1)
    return res

# %%
genes = dict() # root nodes
# separate genes dict() per chr
for _, row in df_by_feature_type['gene'].iterrows():
    gfeat = pd_row2gfeature(row)
    genes[gfeat._id] = gfeat

# %%
dfs_by_chr = [x for _, x in df_by_feature_type['gene'].groupby("chr")]

# %%
for x in df_by_feature_type['gene'].groupby("chr"):
    print(x)
# Out:
# ('chr1',          chr      src feature_type      start        end score strand frame  \
# 0       chr1  Liftoff         gene       6047      13941     .      -     .
# 6       chr1  Liftoff         gene      15080      21429     .      +     .
# 10      chr1  Liftoff         gene      20529      37628     .      -     .
# 22      chr1  Liftoff         gene      52979      54612     .      -     .
# 27      chr1  Liftoff         gene     100966     101472     .      +     .
# ...      ...      ...          ...        ...        ...   ...    ...   ...
# 392483  chr1  Liftoff         gene  248311348  248368818     .      +     .
# 392490  chr1  Liftoff         gene  248312352  248312457     .      +     .
# 392494  chr1  Liftoff         gene  248312745  248312816     .      +     .
# 392535  chr1  Liftoff         gene  248351319  248351420     .      -     .
# 392542  chr1  Liftoff         gene  248375192  248375720     .      +     .
#
#                                                attributes
# 0       ID=LOC124900618;gene_name=LOC124900618;db_xref...
# 6       ID=LOC124905335_1;gene_name=LOC124905335;db_xr...
# 10      ID=LOC112268260;gene_name=LOC112268260;db_xref...
# 22      ID=LOC101928626;gene_name=LOC101928626;db_xref...
# 27      ID=WBP1LP7;gene_name=WBP1LP7;db_xref=HGNC:HGNC...
# ...                                                   ...
# 392483  ID=PGBD2;gene_name=PGBD2;db_xref=HGNC:HGNC:193...
# 392490  ID=TRL-CAA4-1;gene_name=TRL-CAA4-1;db_xref=HGN...
# 392494  ID=TRE-CTC2-1;gene_name=TRE-CTC2-1;db_xref=HGN...
# 392535  ID=RNU6-1205P;gene_name=RNU6-1205P;db_xref=HGN...
# 392542  ID=RPL23AP25;gene_name=RPL23AP25;db_xref=HGNC:...
#
# [5770 rows x 9 columns])
# ('chr10',            chr      src feature_type      start        end score strand frame  \
# 2058703  chr10  Liftoff         gene       4728       8582     .      +     .
# 2058708  chr10  Liftoff         gene       6891       8246     .      -     .
# 2058712  chr10  Liftoff         gene      35500      37819     .      +     .
# 2058721  chr10  Liftoff         gene      39416      69557     .      -     .
# 2058760  chr10  Liftoff         gene      72910      79173     .      -     .
# ...        ...      ...          ...        ...        ...   ...    ...   ...
# 2243266  chr10  Liftoff         gene  134714578  134716102     .      +     .
# 2243267  chr10  Liftoff         gene  134717888  134719412     .      +     .
# 2243268  chr10  Liftoff         gene  134721198  134722722     .      +     .
# 2243269  chr10  Liftoff         gene  134724508  134726032     .      +     .
# 2243270  chr10  Liftoff         gene  134745871  134746398     .      +     .
#
#                                                 attributes
# 2058703  ID=LOC102723376;gene_name=LOC102723376;db_xref...
# 2058708  ID=LOC124904234_4;gene_name=LOC124904234;db_xr...
# 2058712  ID=LOC124902360;gene_name=LOC124902360;db_xref...
# 2058721  ID=TUBB8;gene_name=TUBB8;db_xref=MIM:616768;de...
# 2058760  ID=IL9RP2;gene_name=IL9RP2;db_xref=HGNC:HGNC:6...
# ...                                                    ...
# 2243266  ID=DUX4L24_10;gene_name=DUX4L24;db_xref=HGNC:H...
# 2243267  ID=DUX4L24_13;gene_name=DUX4L24;db_xref=HGNC:H...
# 2243268  ID=DUX4L24_12;gene_name=DUX4L24;db_xref=HGNC:H...
# 2243269  ID=DUX4L24_2;gene_name=DUX4L24;db_xref=HGNC:HG...
# 2243270  ID=RPL23AP60;gene_name=RPL23AP60;db_xref=HGNC:...
#
# [2406 rows x 9 columns])
# ('chr11',            chr      src feature_type      start        end score strand frame  \
# 2243271  chr11  Liftoff         gene       3434       5924     .      +     .
# 2243276  chr11  Liftoff         gene       5962      21167     .      -     .
# 2243289  chr11  Liftoff         gene      21340      27037     .      +     .
# 2243294  chr11  Liftoff         gene      21922      22059     .      +     .
# 2243299  chr11  Liftoff         gene      26230      27700     .      -     .
# ...        ...      ...          ...        ...        ...   ...    ...   ...
# 2455714  chr11  Liftoff         gene  134998908  134999487     .      +     .
# 2455718  chr11  Liftoff         gene  135033271  135034718     .      +     .
# 2455721  chr11  Liftoff         gene  135042771  135055877     .      -     .
# 2455730  chr11  Liftoff         gene  135052572  135058933     .      +     .
# 2455742  chr11  Liftoff         gene  135120399  135124319     .      -     .
#
#                                                 attributes
# 2243271  ID=DDX11L17;gene_name=DDX11L17;db_xref=HGNC:HG...
# 2243276  ID=LOC100996442;gene_name=LOC100996442;db_xref...
# 2243289  ID=MIR1302-2HG;gene_name=MIR1302-2HG;db_xref=H...
# 2243294  ID=MIR1302-2;gene_name=MIR1302-2;db_xref=miRBa...
# 2243299  ID=FAM138A;gene_name=FAM138A;db_xref=HGNC:HGNC...
# ...                                                    ...
# 2455714  ID=LINC02697;gene_name=LINC02697;db_xref=HGNC:...
# 2455718  ID=LOC100507548;gene_name=LOC100507548;db_xref...
# 2455721  ID=LINC02717;gene_name=LINC02717;db_xref=HGNC:...
# 2455730  ID=LOC105369587;gene_name=LOC105369587;db_xref...
# 2455742  ID=LINC02684;gene_name=LINC02684;db_xref=HGNC:...
#
# [3148 rows x 9 columns])
# ('chr12',            chr      src feature_type      start        end score strand frame  \
# 2455751  chr12  Liftoff         gene       5295       7527     .      +     .
# 2455752  chr12  Liftoff         gene       7478      23077     .      -     .
# 2455765  chr12  Liftoff         gene      23417      30413     .      +     .
# 2455770  chr12  Liftoff         gene      30786      32250     .      -     .
# 2455775  chr12  Liftoff         gene      58888     174477     .      +     .
# ...        ...      ...          ...        ...        ...   ...    ...   ...
# 2674344  chr12  Liftoff         gene  133182782  133183303     .      +     .
# 2674345  chr12  Liftoff         gene  133187943  133216780     .      +     .
# 2674356  chr12  Liftoff         gene  133238807  133272083     .      +     .
# 2674449  chr12  Liftoff         gene  133275564  133293187     .      -     .
# 2674600  chr12  Liftoff         gene  133295645  133295748     .      -     .
#
#                                                 attributes
# 2455751  ID=DDX11L8;gene_name=DDX11L8;db_xref=HGNC:HGNC...
# 2455752  ID=WASH8P;gene_name=WASH8P;db_xref=HGNC:HGNC:5...
# 2455765  ID=LOC107987170;gene_name=LOC107987170;db_xref...
# 2455770  ID=FAM138D;gene_name=FAM138D;db_xref=HGNC:HGNC...
# 2455775  ID=IQSEC3;gene_name=IQSEC3;db_xref=MIM:612118;...
# ...                                                    ...
# 2674344  ID=RPL23AP67;gene_name=RPL23AP67;db_xref=HGNC:...
# 2674345  ID=ZNF10;gene_name=ZNF10;db_xref=MIM:194538;de...
# 2674356  ID=ZNF268;gene_name=ZNF268;db_xref=MIM:604753;...
# 2674449  ID=ANHX;gene_name=ANHX;db_xref=HGNC:HGNC:40024...
# 2674600  ID=RNU6-717P;gene_name=RNU6-717P;db_xref=HGNC:...
#
# [2765 rows x 9 columns])
# ('chr13',            chr      src feature_type      start        end score strand frame  \
# 2674601  chr13  Liftoff         gene    5228526    5291184     .      +     .
# 2674608  chr13  Liftoff         gene    5268076    5269025     .      -     .
# 2674609  chr13  Liftoff         gene    5277528    5293756     .      -     .
# 2674616  chr13  Liftoff         gene    5295341    5317629     .      -     .
# 2674641  chr13  Liftoff         gene    5320550    5320705     .      -     .
# ...        ...      ...          ...        ...        ...   ...    ...   ...
# 2764639  chr13  Liftoff         gene  113500858  113502780     .      +     .
# 2764643  chr13  Liftoff         gene  113515650  113516256     .      +     .
# 2764644  chr13  Liftoff         gene  113523561  113536364     .      +     .
# 2764665  chr13  Liftoff         gene  113538799  113542990     .      -     .
# 2764670  chr13  Liftoff         gene  113547389  113560605     .      +     .
#
#                                                 attributes
# 2674601  ID=LOC105379566_1;gene_name=LOC105379566;db_xr...
# 2674608  ID=SNX18P17_1;gene_name=SNX18P17;db_xref=HGNC:...
# 2674609  ID=ANKRD20A12P;gene_name=ANKRD20A12P;db_xref=H...
# 2674616  ID=LOC102723382_1;gene_name=LOC102723382;db_xr...
# 2674641  ID=ASNSP2_9;gene_name=ASNSP2;db_xref=HGNC:HGNC...
# ...                                                    ...
# 2764639  ID=LOC124903222;gene_name=LOC124903222;db_xref...
# 2764643  ID=CLCP2;gene_name=CLCP2;db_xref=HGNC:HGNC:425...
# 2764644  ID=CHAMP1;gene_name=CHAMP1;db_xref=MIM:616327;...
# 2764665  ID=LINC01054;gene_name=LINC01054;db_xref=HGNC:...
# 2764670  ID=LOC112268113;gene_name=LOC112268113;db_xref...
#
# [1937 rows x 9 columns])
# ('chr14',            chr      src feature_type      start        end score strand frame  \
# 2764675  chr14  Liftoff         gene     235176     235692     .      -     .
# 2764676  chr14  Liftoff         gene     252410     259207     .      -     .
# 2764680  chr14  Liftoff         gene     254803     258851     .      +     .
# 2764681  chr14  Liftoff         gene     641139     642420     .      +     .
# 2764685  chr14  Liftoff         gene    1529328    1573496     .      +     .
# ...        ...      ...          ...        ...        ...   ...    ...   ...
# 2891630  chr14  Liftoff         gene  101140915  101141189     .      -     .
# 2891634  chr14  Liftoff         gene  101142933  101143385     .      -     .
# 2891640  chr14  Liftoff         gene  101148076  101148479     .      -     .
# 2891646  chr14  Liftoff         gene  101149874  101150310     .      -     .
# 2891652  chr14  Liftoff         gene  101154845  101155136     .      -     .
#
#                                                 attributes
# 2764675  ID=MTCO3P39_4;gene_name=MTCO3P39;db_xref=HGNC:...
# 2764676  ID=LOC124905337;gene_name=LOC124905337;db_xref...
# 2764680  ID=LOC102723462;gene_name=LOC102723462;db_xref...
# 2764681  ID=LOC107984150_5;gene_name=LOC107984150;db_xr...
# 2764685  ID=LOC101930100_1;gene_name=LOC101930100;db_xr...
# ...                                                    ...
# 2891630  ID=IGHVII-78-1;gene_name=IGHVII-78-1;db_xref=I...
# 2891634  ID=IGHV3-79;gene_name=IGHV3-79;db_xref=IMGT/GE...
# 2891640  ID=IGHV4-80;gene_name=IGHV4-80;db_xref=IMGT/GE...
# 2891646  ID=IGHV7-81;gene_name=IGHV7-81;db_xref=IMGT/GE...
# 2891652  ID=IGHVIII-82;gene_name=IGHVIII-82;db_xref=IMG...
#
# [2379 rows x 9 columns])
# ('chr15',            chr      src feature_type     start       end score strand frame  \
# 2891656  chr15  Liftoff         gene     13013     20512     .      +     .
# 2891661  chr15  Liftoff         gene     48496     50920     .      -     .
# 2891662  chr15  Liftoff         gene     52613     75609     .      +     .
# 2891675  chr15  Liftoff         gene     52857     53478     .      -     .
# 2891680  chr15  Liftoff         gene    162597    163100     .      -     .
# ...        ...      ...          ...       ...       ...   ...    ...   ...
# 3042158  chr15  Liftoff         gene  99724180  99725650     .      +     .
# 3042163  chr15  Liftoff         gene  99729754  99729891     .      -     .
# 3042168  chr15  Liftoff         gene  99730108  99745901     .      +     .
# 3042181  chr15  Liftoff         gene  99742820  99742887     .      +     .
# 3042188  chr15  Liftoff         gene  99745854  99748389     .      -     .
#
#                                                 attributes
# 2891656  ID=LOC107986338_1;gene_name=LOC107986338;db_xr...
# 2891661  ID=LOC102723528;gene_name=LOC102723528;db_xref...
# 2891662  ID=LOC112268317_2;gene_name=LOC112268317;db_xr...
# 2891675  ID=LOC124905333_2;gene_name=LOC124905333;db_xr...
# 2891680  ID=LOC100419924_5;gene_name=LOC100419924;db_xr...
# ...                                                    ...
# 3042158  ID=FAM138E;gene_name=FAM138E;db_xref=HGNC:HGNC...
# 3042163  ID=MIR1302-10;gene_name=MIR1302-10;db_xref=miR...
# 3042168  ID=WASH3P;gene_name=WASH3P;db_xref=HGNC:HGNC:2...
# 3042181  ID=MIR6859-3;gene_name=MIR6859-3;db_xref=miRBa...
# 3042188  ID=DDX11L9;gene_name=DDX11L9;db_xref=HGNC:HGNC...
#
# [2265 rows x 9 columns])
# ('chr16',            chr      src feature_type     start       end score strand frame  \
# 3042197  chr16  Liftoff         gene      4481      7016     .      +     .
# 3042202  chr16  Liftoff         gene      7007     11013     .      -     .
# 3042203  chr16  Liftoff         gene      9974     10041     .      -     .
# 3042210  chr16  Liftoff         gene     15844     18037     .      +     .
# 3042214  chr16  Liftoff         gene     21851     30058     .      -     .
# ...        ...      ...          ...       ...       ...   ...    ...   ...
# 3199282  chr16  Liftoff         gene  96265822  96268407     .      +     .
# 3199283  chr16  Liftoff         gene  96265822  96268407     .      -     .
# 3199284  chr16  Liftoff         gene  96287441  96298462     .      -     .
# 3199289  chr16  Liftoff         gene  96309529  96310799     .      +     .
# 3199296  chr16  Liftoff         gene  96318486  96318958     .      +     .
#
#                                                 attributes
# 3042197  ID=DDX11L10;gene_name=DDX11L10;db_xref=HGNC:HG...
# 3042202  ID=WASH4P;gene_name=WASH4P;db_xref=HGNC:HGNC:1...
# 3042203  ID=MIR6859-4;gene_name=MIR6859-4;db_xref=miRBa...
# 3042210  ID=WASIR2;gene_name=WASIR2;db_xref=HGNC:HGNC:3...
# 3042214  ID=IL9RP3;gene_name=IL9RP3;db_xref=HGNC:HGNC:6...
# ...                                                    ...
# 3199282  ID=SEPTIN14P16;gene_name=SEPTIN14P16;db_xref=H...
# 3199283  ID=SEPTIN14P22_9;gene_name=SEPTIN14P22;db_xref...
# 3199284  ID=LOC107987240;gene_name=LOC107987240;db_xref...
# 3199289  ID=LOC101929828_1;gene_name=LOC101929828;db_xr...
# 3199296  ID=RPL23AP24;gene_name=RPL23AP24;db_xref=HGNC:...
#
# [2215 rows x 9 columns])
# ('chr17',            chr      src feature_type     start       end score strand frame  \
# 3199297  chr17  Liftoff         gene     43010     44511     .      +     .
# 3199305  chr17  Liftoff         gene     48059     84879     .      -     .
# 3199390  chr17  Liftoff         gene     87053     90480     .      -     .
# 3199394  chr17  Liftoff         gene    103408    104940     .      -     .
# 3199398  chr17  Liftoff         gene    117331    273178     .      -     .
# ...        ...      ...          ...       ...       ...   ...    ...   ...
# 3415653  chr17  Liftoff         gene  84166186  84240296     .      +     .
# 3415659  chr17  Liftoff         gene  84192274  84200571     .      +     .
# 3415663  chr17  Liftoff         gene  84216963  84223382     .      +     .
# 3415668  chr17  Liftoff         gene  84242296  84251760     .      -     .
# 3415673  chr17  Liftoff         gene  84250806  84264715     .      +     .
#
#                                                 attributes
# 3199297  ID=SCGB1C2;gene_name=SCGB1C2;db_xref=HGNC:HGNC...
# 3199305  ID=DOC2B;gene_name=DOC2B;db_xref=MIM:604568;de...
# 3199390  ID=LINC02091;gene_name=LINC02091;db_xref=HGNC:...
# 3199394  ID=LOC124903889;gene_name=LOC124903889;db_xref...
# 3199398  ID=RPH3AL;gene_name=RPH3AL;db_xref=MIM:604881;...
# ...                                                    ...
# 3415653  ID=LOC101929650;gene_name=LOC101929650;db_xref...
# 3415659  ID=LOC124904105;gene_name=LOC124904105;db_xref...
# 3415663  ID=LOC105371948;gene_name=LOC105371948;db_xref...
# 3415668  ID=LOC100505909;gene_name=LOC100505909;db_xref...
# 3415673  ID=RPL23AP87;gene_name=RPL23AP87;db_xref=HGNC:...
#
# [2704 rows x 9 columns])
# ('chr18',            chr      src feature_type     start       end score strand frame  \
# 3415679  chr18  Liftoff         gene      3853      7709     .      +     .
# 3415684  chr18  Liftoff         gene      6017      7372     .      -     .
# 3415688  chr18  Liftoff         gene     34659     38818     .      +     .
# 3415712  chr18  Liftoff         gene     39023     40250     .      -     .
# 3415713  chr18  Liftoff         gene     57357     61724     .      +     .
# ...        ...      ...          ...       ...       ...   ...    ...   ...
# 3498139  chr18  Liftoff         gene  80354164  80354706     .      +     .
# 3498140  chr18  Liftoff         gene  80385719  80416803     .      +     .
# 3498176  chr18  Liftoff         gene  80424381  80454890     .      +     .
# 3498185  chr18  Liftoff         gene  80433688  80523977     .      -     .
# 3498193  chr18  Liftoff         gene  80455431  80459895     .      -     .
#
#                                                 attributes
# 3415679  ID=LOC102723376_3;gene_name=LOC102723376;db_xr...
# 3415684  ID=LOC124904234_1;gene_name=LOC124904234;db_xr...
# 3415688  ID=LOC105371950_2;gene_name=LOC105371950;db_xr...
# 3415712  ID=TUBB8P8_3;gene_name=TUBB8P8;db_xref=HGNC:HG...
# 3415713  ID=LINC02564;gene_name=LINC02564;db_xref=HGNC:...
# ...                                                    ...
# 3498139  ID=SLC25A6P4;gene_name=SLC25A6P4;db_xref=HGNC:...
# 3498140  ID=ADNP2;gene_name=ADNP2;db_xref=MIM:617422;de...
# 3498176  ID=PARD6G-AS1;gene_name=PARD6G-AS1;db_xref=HGN...
# 3498185  ID=PARD6G;gene_name=PARD6G;db_xref=MIM:608976;...
# 3498193  ID=LOC124904337;gene_name=LOC124904337;db_xref...
#
# [1119 rows x 9 columns])
# ('chr19',            chr      src feature_type     start       end score strand frame  \
# 3498198  chr19  Liftoff         gene      4460      6999     .      +     .
# 3498203  chr19  Liftoff         gene      9960     10027     .      -     .
# 3498210  chr19  Liftoff         gene     11934     21953     .      -     .
# 3498215  chr19  Liftoff         gene     22368     27986     .      +     .
# 3498220  chr19  Liftoff         gene     22960     23097     .      +     .
# ...        ...      ...          ...       ...       ...   ...    ...   ...
# 3668923  chr19  Liftoff         gene  61656863  61672475     .      +     .
# 3668931  chr19  Liftoff         gene  61659609  61671251     .      -     .
# 3669029  chr19  Liftoff         gene  61673077  61682061     .      +     .
# 3669033  chr19  Liftoff         gene  61683779  61687068     .      +     .
# 3669037  chr19  Liftoff         gene  61696473  61697001     .      +     .
#
#                                                 attributes
# 3498198  ID=DDX11L1;gene_name=DDX11L1;db_xref=HGNC:HGNC...
# 3498203  ID=MIR6859-1;gene_name=MIR6859-1;db_xref=miRBa...
# 3498210  ID=WASH5P;gene_name=WASH5P;db_xref=HGNC:HGNC:3...
# 3498215  ID=LOC105376912;gene_name=LOC105376912;db_xref...
# 3498220  ID=MIR1302-11;gene_name=MIR1302-11;db_xref=miR...
# ...                                                    ...
# 3668923  ID=MZF1-AS1;gene_name=MZF1-AS1;db_xref=HGNC:HG...
# 3668931  ID=MZF1;gene_name=MZF1;db_xref=MIM:194550;desc...
# 3669029  ID=CENPBD2P;gene_name=CENPBD2P;db_xref=HGNC:HG...
# 3669033  ID=LOC107987272;gene_name=LOC107987272;db_xref...
# 3669037  ID=RPL23AP79;gene_name=RPL23AP79;db_xref=HGNC:...
#
# [2678 rows x 9 columns])
# ('chr2',          chr      src feature_type      start        end score strand frame  \
# 392543  chr2  Liftoff         gene      32180      39871     .      -     .
# 392568  chr2  Liftoff         gene     154770     184567     .      -     .
# 392583  chr2  Liftoff         gene     218391     265079     .      -     .
# 392718  chr2  Liftoff         gene     265202     278542     .      +     .
# 392760  chr2  Liftoff         gene     279817     288348     .      -     .
# ...      ...      ...          ...        ...        ...   ...    ...   ...
# 743439  chr2  Liftoff         gene  242631950  242634517     .      +     .
# 743440  chr2  Liftoff         gene  242631950  242634517     .      -     .
# 743441  chr2  Liftoff         gene  242653848  242664886     .      -     .
# 743446  chr2  Liftoff         gene  242676118  242677388     .      +     .
# 743453  chr2  Liftoff         gene  242685066  242685590     .      +     .
#
#                                                attributes
# 392543  ID=FAM110C;gene_name=FAM110C;db_xref=MIM:61139...
# 392568  ID=LOC105373324;gene_name=LOC105373324;db_xref...
# 392583  ID=SH3YL1;gene_name=SH3YL1;db_xref=MIM:617314;...
# 392718  ID=ACP1;gene_name=ACP1;db_xref=MIM:171500;desc...
# 392760  ID=ALKAL2;gene_name=ALKAL2;db_xref=MIM:619671;...
# ...                                                   ...
# 743439  ID=SEPTIN14P2;gene_name=SEPTIN14P2;db_xref=HGN...
# 743440  ID=SEPTIN14P22_16;gene_name=SEPTIN14P22;db_xre...
# 743441  ID=LOC107987240_3;gene_name=LOC107987240;db_xr...
# 743446  ID=LOC101929828;gene_name=LOC101929828;db_xref...
# 743453  ID=RPL23AP88;gene_name=RPL23AP88;db_xref=HGNC:...
#
# [4284 rows x 9 columns])
# ('chr20',            chr      src feature_type     start       end score strand frame  \
# 3669038  chr20  Liftoff         gene     11293     11818     .      -     .
# 3669039  chr20  Liftoff         gene     26004     37073     .      +     .
# 3669046  chr20  Liftoff         gene     56567     65815     .      -     .
# 3669101  chr20  Liftoff         gene     67990     70787     .      -     .
# 3669111  chr20  Liftoff         gene     72708     75239     .      +     .
# ...        ...      ...          ...       ...       ...   ...    ...   ...
# 3750983  chr20  Liftoff         gene  66181901  66187731     .      -     .
# 3750991  chr20  Liftoff         gene  66186644  66186781     .      -     .
# 3750996  chr20  Liftoff         gene  66187777  66202791     .      +     .
# 3751009  chr20  Liftoff         gene  66199719  66199786     .      +     .
# 3751016  chr20  Liftoff         gene  66202741  66205279     .      -     .
#
#                                                 attributes
# 3669038  ID=RPL23AP21;gene_name=RPL23AP21;db_xref=HGNC:...
# 3669039  ID=LOC124903815_1;gene_name=LOC124903815;db_xr...
# 3669046  ID=LOC101929823;gene_name=LOC101929823;db_xref...
# 3669101  ID=LOC124903814;gene_name=LOC124903814;db_xref...
# 3669111  ID=DDX11L9_1;gene_name=DDX11L9;db_xref=HGNC:HG...
# ...                                                    ...
# 3750983  ID=LOC124907875_1;gene_name=LOC124907875;db_xr...
# 3750991  ID=MIR1302-3_1;gene_name=MIR1302-3;db_xref=miR...
# 3750996  ID=WASH7P;gene_name=WASH7P;db_xref=HGNC:HGNC:3...
# 3751009  ID=MIR6859-1_1;gene_name=MIR6859-1;db_xref=miR...
# 3751016  ID=DDX11L5_1;gene_name=DDX11L5;db_xref=HGNC:HG...
#
# [1503 rows x 9 columns])
# ('chr21',            chr      src feature_type     start       end score strand frame  \
# 3751021  chr21  Liftoff         gene      9957     17448     .      +     .
# 3751026  chr21  Liftoff         gene     45409     47833     .      -     .
# 3751027  chr21  Liftoff         gene     49526     72559     .      +     .
# 3751040  chr21  Liftoff         gene     49770     50391     .      -     .
# 3751045  chr21  Liftoff         gene    224822    225325     .      -     .
# ...        ...      ...          ...       ...       ...   ...    ...   ...
# 3791739  chr21  Liftoff         gene  44984829  44991348     .      -     .
# 3791752  chr21  Liftoff         gene  45021936  45051495     .      +     .
# 3792006  chr21  Liftoff         gene  45039480  45040465     .      -     .
# 3792007  chr21  Liftoff         gene  45053753  45059934     .      +     .
# 3792011  chr21  Liftoff         gene  45077112  45077637     .      +     .
#
#                                                 attributes
# 3751021  ID=LOC107986338_3;gene_name=LOC107986338;db_xr...
# 3751026  ID=LOC102723528_1;gene_name=LOC102723528;db_xr...
# 3751027  ID=LOC112268317;gene_name=LOC112268317;db_xref...
# 3751040  ID=LOC124905333;gene_name=LOC124905333;db_xref...
# 3751045  ID=LOC100419924_4;gene_name=LOC100419924;db_xr...
# ...                                                    ...
# 3791739  ID=S100B;gene_name=S100B;db_xref=MIM:176990;de...
# 3791752  ID=PRMT2;gene_name=PRMT2;db_xref=MIM:601961;de...
# 3792006  ID=DSTNP1;gene_name=DSTNP1;db_xref=HGNC:HGNC:2...
# 3792007  ID=LOC124905058;gene_name=LOC124905058;db_xref...
# 3792011  ID=RPL23AP4;gene_name=RPL23AP4;db_xref=HGNC:HG...
#
# [1066 rows x 9 columns])
# ('chr22',            chr      src feature_type     start       end score strand frame  \
# 3792012  chr22  Liftoff         gene     11523     19018     .      +     .
# 3792017  chr22  Liftoff         gene     46884     49509     .      -     .
# 3792018  chr22  Liftoff         gene     51202     74199     .      +     .
# 3792031  chr22  Liftoff         gene     51446     52067     .      -     .
# 3792036  chr22  Liftoff         gene    230408    270092     .      +     .
# ...        ...      ...          ...       ...       ...   ...    ...   ...
# 3872240  chr22  Liftoff         gene  51249409  51251748     .      -     .
# 3872244  chr22  Liftoff         gene  51251783  51258912     .      +     .
# 3872256  chr22  Liftoff         gene  51267952  51268966     .      -     .
# 3872257  chr22  Liftoff         gene  51270584  51313167     .      +     .
# 3872263  chr22  Liftoff         gene  51281003  51297133     .      -     .
#
#                                                 attributes
# 3792012  ID=LOC107986338_2;gene_name=LOC107986338;db_xr...
# 3792017  ID=LOC105374377_1;gene_name=LOC105374377;db_xr...
# 3792018  ID=LOC112268317_1;gene_name=LOC112268317;db_xr...
# 3792031  ID=LOC124905333_3;gene_name=LOC124905333;db_xr...
# 3792036  ID=LOC105379417;gene_name=LOC105379417;db_xref...
# ...                                                    ...
# 3872240  ID=LOC105373100;gene_name=LOC105373100;db_xref...
# 3872244  ID=ACR;gene_name=ACR;db_xref=MIM:102480;descri...
# 3872256  ID=LOC150417;gene_name=LOC150417;db_xref=GeneI...
# 3872257  ID=RPL23AP82;gene_name=RPL23AP82;db_xref=HGNC:...
# 3872263  ID=RABL2B;gene_name=RABL2B;db_xref=MIM:605413;...
#
# [1448 rows x 9 columns])
# ('chr3',           chr      src feature_type      start        end score strand frame  \
# 743454   chr3  Liftoff         gene       3392      16126     .      +     .
# 743460   chr3  Liftoff         gene      46090      59337     .      +     .
# 743465   chr3  Liftoff         gene      59511      61746     .      +     .
# 743469   chr3  Liftoff         gene     115218     124077     .      +     .
# 743482   chr3  Liftoff         gene     138650     139013     .      +     .
# ...       ...      ...          ...        ...        ...   ...    ...   ...
# 1014671  chr3  Liftoff         gene  201056319  201057262     .      -     .
# 1014672  chr3  Liftoff         gene  201073667  201075135     .      +     .
# 1014677  chr3  Liftoff         gene  201075508  201079447     .      -     .
# 1014682  chr3  Liftoff         gene  201079785  201097323     .      +     .
# 1014695  chr3  Liftoff         gene  201097274  201099490     .      -     .
#
#                                                 attributes
# 743454   ID=LINC01986;gene_name=LINC01986;db_xref=HGNC:...
# 743460   ID=LOC105376921;gene_name=LOC105376921;db_xref...
# 743465   ID=LOC107986040;gene_name=LOC107986040;db_xref...
# 743469   ID=LOC107986057;gene_name=LOC107986057;db_xref...
# 743482   ID=LOC124909336;gene_name=LOC124909336;db_xref...
# ...                                                    ...
# 1014671  ID=OR4G4P;gene_name=OR4G4P;db_xref=HGNC:HGNC:1...
# 1014672  ID=FAM138D_1;gene_name=FAM138D;db_xref=HGNC:HG...
# 1014677  ID=LOC107987170_1;gene_name=LOC107987170;db_xr...
# 1014682  ID=WASH8P_1;gene_name=WASH8P;db_xref=HGNC:HGNC...
# 1014695  ID=DDX11L8_1;gene_name=DDX11L8;db_xref=HGNC:HG...
#
# [3271 rows x 9 columns])
# ('chr4',           chr      src feature_type      start        end score strand frame  \
# 1014696  chr4  Liftoff         gene      12961      20452     .      +     .
# 1014701  chr4  Liftoff         gene      48328      50953     .      -     .
# 1014702  chr4  Liftoff         gene      52753      87637     .      +     .
# 1014730  chr4  Liftoff         gene      52890      53511     .      -     .
# 1014731  chr4  Liftoff         gene     105187     107364     .      -     .
# ...       ...      ...          ...        ...        ...   ...    ...   ...
# 1192625  chr4  Liftoff         gene  193536345  193536428     .      +     .
# 1192630  chr4  Liftoff         gene  193538284  193539568     .      +     .
# 1192631  chr4  Liftoff         gene  193539651  193539734     .      +     .
# 1192636  chr4  Liftoff         gene  193541579  193553139     .      +     .
# 1192659  chr4  Liftoff         gene  193562943  193563471     .      +     .
#
#                                                 attributes
# 1014696  ID=LOC107986338;gene_name=LOC107986338;db_xref...
# 1014701  ID=LOC105374377;gene_name=LOC105374377;db_xref...
# 1014702  ID=ZNF595;gene_name=ZNF595;db_xref=HGNC:HGNC:2...
# 1014730  ID=LOC124905333_1;gene_name=LOC124905333;db_xr...
# 1014731  ID=WEE1P1;gene_name=WEE1P1;db_xref=HGNC:HGNC:5...
# ...                                                    ...
# 1192625  ID=MIR8078_32;gene_name=MIR8078;db_xref=miRBas...
# 1192630  ID=DUX4L6_12;gene_name=DUX4L6;db_xref=HGNC:HGN...
# 1192631  ID=MIR8078_10;gene_name=MIR8078;db_xref=miRBas...
# 1192636  ID=DUX4;gene_name=DUX4;db_xref=MIM:606009;desc...
# 1192659  ID=RPL23AP84;gene_name=RPL23AP84;db_xref=HGNC:...
#
# [2823 rows x 9 columns])
# ('chr5',           chr      src feature_type      start        end score strand frame  \
# 1192660  chr5  Liftoff         gene      15645      16644     .      -     .
# 1192664  chr5  Liftoff         gene      16789      41588     .      -     .
# 1192673  chr5  Liftoff         gene      48762      49656     .      +     .
# 1192674  chr5  Liftoff         gene     104255     181320     .      +     .
# 1192713  chr5  Liftoff         gene     182851     187790     .      +     .
# ...       ...      ...          ...        ...        ...   ...    ...   ...
# 1360281  chr5  Liftoff         gene  181942043  181942549     .      -     .
# 1360282  chr5  Liftoff         gene  181942043  181942549     .      +     .
# 1360283  chr5  Liftoff         gene  181981932  182025604     .      +     .
# 1360300  chr5  Liftoff         gene  182017086  182023463     .      -     .
# 1360304  chr5  Liftoff         gene  182034678  182035205     .      +     .
#
#                                                 attributes
# 1192660  ID=LOC124900928;gene_name=LOC124900928;db_xref...
# 1192664  ID=LOC105374602;gene_name=LOC105374602;db_xref...
# 1192673  ID=LOC100128803;gene_name=LOC100128803;db_xref...
# 1192674  ID=PLEKHG4B;gene_name=PLEKHG4B;db_xref=HGNC:HG...
# 1192713  ID=LRRC14B;gene_name=LRRC14B;db_xref=HGNC:HGNC...
# ...                                                    ...
# 1360281  ID=WBP1LP4;gene_name=WBP1LP4;db_xref=HGNC:HGNC...
# 1360282  ID=WBP1LP9_5;gene_name=WBP1LP9;db_xref=HGNC:HG...
# 1360283  ID=LOC124901156;gene_name=LOC124901156;db_xref...
# 1360300  ID=LOC124901157;gene_name=LOC124901157;db_xref...
# 1360304  ID=RPL23AP45;gene_name=RPL23AP45;db_xref=HGNC:...
#
# [2912 rows x 9 columns])
# ('chr6',           chr      src feature_type      start        end score strand frame  \
# 1360305  chr6  Liftoff         gene      35295      42660     .      +     .
# 1360315  chr6  Liftoff         gene      36377      60386     .      -     .
# 1360325  chr6  Liftoff         gene      85872      92074     .      +     .
# 1360334  chr6  Liftoff         gene     147423     206310     .      +     .
# 1360406  chr6  Liftoff         gene     250136     269771     .      +     .
# ...       ...      ...          ...        ...        ...   ...    ...   ...
# 1556194  chr6  Liftoff         gene  172013163  172014100     .      +     .
# 1556195  chr6  Liftoff         gene  172024569  172025075     .      -     .
# 1556196  chr6  Liftoff         gene  172024569  172025075     .      +     .
# 1556197  chr6  Liftoff         gene  172065653  172113407     .      +     .
# 1556205  chr6  Liftoff         gene  172104074  172110409     .      -     .
#
#                                                 attributes
# 1360305  ID=LOC105374869;gene_name=LOC105374869;db_xref...
# 1360315  ID=LOC285766;gene_name=LOC285766;db_xref=GeneI...
# 1360325  ID=LOC105374870;gene_name=LOC105374870;db_xref...
# 1360334  ID=DUSP22;gene_name=DUSP22;db_xref=MIM:616778;...
# 1360406  ID=IRF4;gene_name=IRF4;db_xref=MIM:601900;desc...
# ...                                                    ...
# 1556194  ID=OR4F7P;gene_name=OR4F7P;db_xref=HGNC:HGNC:1...
# 1556195  ID=WBP1LP12;gene_name=WBP1LP12;db_xref=HGNC:HG...
# 1556196  ID=WBP1LP9_3;gene_name=WBP1LP9;db_xref=HGNC:HG...
# 1556197  ID=LOC101927506;gene_name=LOC101927506;db_xref...
# 1556205  ID=LOC124905335;gene_name=LOC124905335;db_xref...
#
# [3301 rows x 9 columns])
# ('chr7',           chr      src feature_type      start        end score strand frame  \
# 1556209  chr7  Liftoff         gene      11729      18211     .      -     .
# 1556210  chr7  Liftoff         gene      26737      37777     .      +     .
# 1556215  chr7  Liftoff         gene      51018     109050     .      -     .
# 1556223  chr7  Liftoff         gene      56811      59390     .      -     .
# 1556224  chr7  Liftoff         gene      56811      59390     .      +     .
# ...       ...      ...          ...        ...        ...   ...    ...   ...
# 1730894  chr7  Liftoff         gene  160184482  160185226     .      +     .
# 1730898  chr7  Liftoff         gene  160199304  160206797     .      +     .
# 1730905  chr7  Liftoff         gene  160234066  160252596     .      +     .
# 1730912  chr7  Liftoff         gene  160254532  160371379     .      -     .
# 1730998  chr7  Liftoff         gene  160459432  160463764     .      +     .
#
#                                                 attributes
# 1556209  ID=LOC105379555;gene_name=LOC105379555;db_xref...
# 1556210  ID=LOC107987240_1;gene_name=LOC107987240;db_xr...
# 1556215  ID=LOC124900384;gene_name=LOC124900384;db_xref...
# 1556223  ID=SEPTIN14P18;gene_name=SEPTIN14P18;db_xref=H...
# 1556224  ID=SEPTIN14P22_11;gene_name=SEPTIN14P22;db_xre...
# ...                                                    ...
# 1730894  ID=LOC124901794;gene_name=LOC124901794;db_xref...
# 1730898  ID=LOC124901795;gene_name=LOC124901795;db_xref...
# 1730905  ID=LINC00689;gene_name=LINC00689;db_xref=HGNC:...
# 1730912  ID=VIPR2;gene_name=VIPR2;db_xref=MIM:601970;de...
# 1730998  ID=PIP5K1P2;gene_name=PIP5K1P2;db_xref=HGNC:HG...
#
# [3126 rows x 9 columns])
# ('chr8',           chr      src feature_type      start        end score strand frame  \
# 1730999  chr8  Liftoff         gene       5121      29123     .      -     .
# 1731005  chr8  Liftoff         gene      28942      44149     .      +     .
# 1731108  chr8  Liftoff         gene      55078      71159     .      -     .
# 1731115  chr8  Liftoff         gene     100011     103163     .      -     .
# 1731119  chr8  Liftoff         gene     105231     108166     .      -     .
# ...       ...      ...          ...        ...        ...   ...    ...   ...
# 1877763  chr8  Liftoff         gene  146170009  146174042     .      +     .
# 1877766  chr8  Liftoff         gene  146177956  146181191     .      +     .
# 1877769  chr8  Liftoff         gene  146197362  146211529     .      -     .
# 1877770  chr8  Liftoff         gene  146225747  146226557     .      +     .
# 1877771  chr8  Liftoff         gene  146230468  146234031     .      +     .
#
#                                                 attributes
# 1730999  ID=RPL23AP53;gene_name=RPL23AP53;db_xref=HGNC:...
# 1731005  ID=ZNF596;gene_name=ZNF596;db_xref=HGNC:HGNC:2...
# 1731108  ID=LOC101927566;gene_name=LOC101927566;db_xref...
# 1731115  ID=LOC124902052;gene_name=LOC124902052;db_xref...
# 1731119  ID=LOC105377773;gene_name=LOC105377773;db_xref...
# ...                                                    ...
# 1877763  ID=TMED10P1;gene_name=TMED10P1;db_xref=HGNC:HG...
# 1877766  ID=ZNF252P-AS1;gene_name=ZNF252P-AS1;db_xref=H...
# 1877769  ID=LOC124902043;gene_name=LOC124902043;db_xref...
# 1877770  ID=LOC100419763;gene_name=LOC100419763;db_xref...
# 1877771  ID=C8orf33;gene_name=C8orf33;db_xref=HGNC:HGNC...
#
# [2584 rows x 9 columns])
# ('chr9',           chr      src feature_type      start        end score strand frame  \
# 1877783  chr9  Liftoff         gene       5788       8326     .      +     .
# 1877788  chr9  Liftoff         gene       8314      24625     .      -     .
# 1878137  chr9  Liftoff         gene      24282      24419     .      +     .
# 1878142  chr9  Liftoff         gene      28530      30000     .      -     .
# 1878147  chr9  Liftoff         gene      56132      69435     .      +     .
# ...       ...      ...          ...        ...        ...   ...    ...   ...
# 2058694  chr9  Liftoff         gene  150558546  150558923     .      +     .
# 2058695  chr9  Liftoff         gene  150558546  150561131     .      -     .
# 2058696  chr9  Liftoff         gene  150580155  150591170     .      -     .
# 2058701  chr9  Liftoff         gene  150596545  150599866     .      -     .
# 2058702  chr9  Liftoff         gene  150605300  150605772     .      +     .
#
#                                                 attributes
# 1877783  ID=DDX11L5;gene_name=DDX11L5;db_xref=HGNC:HGNC...
# 1877788  ID=WASHC1;gene_name=WASHC1;db_xref=MIM:613632;...
# 1878137  ID=MIR1302-9;gene_name=MIR1302-9;db_xref=miRBa...
# 1878142  ID=FAM138C;gene_name=FAM138C;db_xref=HGNC:HGNC...
# 1878147  ID=LOC124902106;gene_name=LOC124902106;db_xref...
# ...                                                    ...
# 2058694  ID=SEPTIN14P13_1;gene_name=SEPTIN14P13;db_xref...
# 2058695  ID=SEPTIN14P22_3;gene_name=SEPTIN14P22;db_xref...
# 2058696  ID=LOC107987240_2;gene_name=LOC107987240;db_xr...
# 2058701  ID=LOC102723681;gene_name=LOC102723681;db_xref...
# 2058702  ID=RPL23AP47;gene_name=RPL23AP47;db_xref=HGNC:...
#
# [2597 rows x 9 columns])
# ('chrX',           chr      src feature_type      start        end score strand frame  \
# 3873183  chrX  Liftoff         gene     103469     105172     .      -     .
# 3873193  chrX  Liftoff         gene     104531     131585     .      +     .
# 3873327  chrX  Liftoff         gene     132988     149851     .      -     .
# 3873430  chrX  Liftoff         gene     150200     152387     .      +     .
# 3873436  chrX  Liftoff         gene     165039     218172     .      -     .
# ...       ...      ...          ...        ...        ...   ...    ...   ...
# 3992597  chrX  Liftoff         gene  154213358  154214254     .      -     .
# 3992598  chrX  Liftoff         gene  154225700  154241023     .      +     .
# 3992843  chrX  Liftoff         gene  154242570  154244833     .      -     .
# 3992847  chrX  Liftoff         gene  154249567  154252407     .      +     .
# 3992848  chrX  Liftoff         gene  154252395  154254921     .      -     .
#
#                                                 attributes
# 3873183  ID=LOC124905300_1;gene_name=LOC124905300;db_xr...
# 3873193  ID=PLCXD1;gene_name=PLCXD1;db_xref=MIM:300974;...
# 3873327  ID=GTPBP6;gene_name=GTPBP6;db_xref=MIM:300124;...
# 3873430  ID=LINC00685;gene_name=LINC00685;db_xref=HGNC:...
# 3873436  ID=PPP2R3B;gene_name=PPP2R3B;db_xref=MIM:30033...
# ...                                                    ...
# 3992597  ID=TRPC6P1;gene_name=TRPC6P1;db_xref=HGNC:HGNC...
# 3992598  ID=IL9R;gene_name=IL9R;db_xref=MIM:300007;desc...
# 3992843  ID=WASIR1;gene_name=WASIR1;db_xref=HGNC:HGNC:3...
# 3992847  ID=WASH6P;gene_name=WASH6P;db_xref=HGNC:HGNC:3...
# 3992848  ID=DDX11L16;gene_name=DDX11L16;db_xref=HGNC:HG...
#
# [2318 rows x 9 columns])
# ('chrY',           chr      src feature_type     start       end score strand frame  \
# 3992853  chrY  Liftoff         gene    103021    104724     .      -     .
# 3992863  chrY  Liftoff         gene    104083    130734     .      +     .
# 3993011  chrY  Liftoff         gene    132137    148937     .      -     .
# 3993114  chrY  Liftoff         gene    149286    151470     .      +     .
# 3993120  chrY  Liftoff         gene    168543    224805     .      -     .
# ...       ...      ...          ...       ...       ...   ...    ...   ...
# 4008378  chrY  Liftoff         gene  62410346  62411242     .      -     .
# 4008379  chrY  Liftoff         gene  62422543  62436337     .      +     .
# 4008624  chrY  Liftoff         gene  62439553  62441822     .      -     .
# 4008628  chrY  Liftoff         gene  62446556  62449396     .      +     .
# 4008629  chrY  Liftoff         gene  62449384  62451910     .      -     .
#
#                                                 attributes
# 3992853  ID=LOC124905300;gene_name=LOC124905300;db_xref...
# 3992863  ID=PLCXD1_1;gene_name=PLCXD1;db_xref=MIM:30097...
# 3993011  ID=GTPBP6_1;gene_name=GTPBP6;db_xref=MIM:30012...
# 3993114  ID=LINC00685_1;gene_name=LINC00685;db_xref=HGN...
# 3993120  ID=PPP2R3B_1;gene_name=PPP2R3B;db_xref=MIM:300...
# ...                                                    ...
# 4008378  ID=TRPC6P1_3;gene_name=TRPC6P1;db_xref=HGNC:HG...
# 4008379  ID=IL9R_1;gene_name=IL9R;db_xref=MIM:300007;de...
# 4008624  ID=WASIR1_1;gene_name=WASIR1;db_xref=HGNC:HGNC...
# 4008628  ID=WASH6P_1;gene_name=WASH6P;db_xref=HGNC:HGNC...
# 4008629  ID=DDX11L16_1;gene_name=DDX11L16;db_xref=HGNC:...
#
# [693 rows x 9 columns])

# %%
# TODO: implement parallel processing
orphans = []
transcripts = dict()
for _, row in df_by_feature_type['transcript'].iterrows():
    gfeat = pd_row2gfeature(row)
    if not gfeat._parent:
        orphans.append(gfeat)
    genes[gfeat._parent].children[gfeat._id] = gfeat
    transcripts[gfeat._id] = gfeat

# %%
# TODO: parallel
for _, row in df_by_feature_type['exon'].iterrows():
    gfeat = pd_row2gfeature(row)
    transcripts[gfeat._parent].children[gfeat._hash] = gfeat

# %%
transcripts[gfeat._parent].children
# Out:
# {'8d031be0790e5d26836f7c895af67e09f59f74358087992d4b0da56f168a8994': exon:None,-,62449384-62450563,8d031be0790e5d26836f7c895af67e09f59f74358087992d4b0da56f168a8994,
#  '61a43713bdd2cc180fde52d861ef624bf6bf4e1395579d1e06b2bd089d1cfd24': exon:None,-,62451063-62451171,61a43713bdd2cc180fde52d861ef624bf6bf4e1395579d1e06b2bd089d1cfd24,
#  'fa0a84f01da7349aa022bd9ea8588fbb0c272116a093f56e06c1e5b2a5ececd1': exon:None,-,62451557-62451910,fa0a84f01da7349aa022bd9ea8588fbb0c272116a093f56e06c1e5b2a5ececd1}

# %%
with ProcessPoolExecutor(max_workers=24) as executor:
    results = list(executor.map(objectify_df, df_by_feature_type.values()))
# Out:
# Process ForkProcess-100:
# Process ForkProcess-108:
# Exception ignored in: <function _afterFork at 0x7f281a0af600>
# Traceback (most recent call last):
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/logging/__init__.py", line 245, in _afterFork
#     def _afterFork():
# KeyboardInterrupt:
# Process ForkProcess-98:
# Process ForkProcess-103:
# Process ForkProcess-99:
# Process ForkProcess-107:
# Process ForkProcess-97:
# Process ForkProcess-101:
# Process ForkProcess-106:
# Process ForkProcess-104:
# Process ForkProcess-102:
# Process ForkProcess-105:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/queues.py", line 101, in get
#     res = self._recv_bytes()
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/queues.py", line 100, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/hji20/miniconda3/envs/mjol/lib/python3.13/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# Cell In[80], line 2
#       1 with ProcessPoolExecutor(max_workers=24) as executor:
# ----> 2     results = list(executor.map(objectify_df, df_by_feature_type.values()))
#
# File ~/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/process.py:617, in _chain_from_iterable_of_lists(iterable)
#     611 def _chain_from_iterable_of_lists(iterable):
#     612     """
#     613     Specialized implementation of itertools.chain.from_iterable.
#     614     Each item in *iterable* should be a list.  This function is
#     615     careful not to keep references to yielded objects.
#     616     """
# --> 617     for element in iterable:
#     618         element.reverse()
#     619         while element:
#
# File ~/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~/miniconda3/envs/mjol/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.

# %%
df_grouped_by_chr = [group for _, group in df.groupby("chr")]

# %%
def objectify_df(df):
    res = df.apply(pd_row2gfeature, axis=1)
    return res

# %%
with ProcessPoolExecutor(max_workers=24) as executor:
    results = list(executor.map(objectify_df, df_grouped_by_chr))

# %%
test_chr = results[0]

# %%
tree = IntervalTree()
for feature in [gene] + transcripts:
    tree[feature.start:feature.end] = feature

# %%
query_start, query_end = 1100, 1400
overlapping = tree[query_start:query_end]
print(f"Features overlapping {query_start}-{query_end}:")
for iv in overlapping:
    print(iv.data)
# Out:
# Features overlapping 1100-1400:
# seqid='chr1' src='ensembl' feature_type='gene' start=1000 end=9000 score=None strand='+' frame='.' attributes={'ID': 'gene1'}
# seqid='chr1' src='ensembl' feature_type='transcript' start=1200 end=5200 score=None strand='+' frame='.' attributes={'ID': 'tx2', 'Parent': 'gene1'}
# seqid='chr1' src='ensembl' feature_type='transcript' start=1100 end=5100 score=None strand='+' frame='.' attributes={'ID': 'tx1', 'Parent': 'gene1'}
# seqid='chr1' src='ensembl' feature_type='transcript' start=1300 end=5300 score=None strand='+' frame='.' attributes={'ID': 'tx3', 'Parent': 'gene1'}
